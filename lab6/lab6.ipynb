# %%
import numpy as np
from matplotlib import pyplot as plt

# tworzymy tablice o wymiarach 128x128x3 (3 kanaly to RGB)
# uzupelnioną zerami = kolor czarny
data = np.zeros((128, 128, 3), dtype=np.uint8)


# chcemy zeby obrazek byl czarnobialy,
# wiec wszystkie trzy kanaly rgb uzupelniamy tymi samymi liczbami
# napiszmy do tego funkcje
def draw(img, x, y, color):
    img[x, y] = [color, color, color]


# zamalowanie 4 pikseli w lewym górnym rogu
draw(data, 5, 5, 100)
draw(data, 6, 6, 100)
draw(data, 5, 6, 255)
draw(data, 6, 5, 255)


# rysowanie kilku figur na obrazku
for i in range(128):
    for j in range(128):
        if (i-64)**2 + (j-64)**2 < 900:
            draw(data, i, j, 200)
        elif i > 100 and j > 100:
            draw(data, i, j, 255)
        elif (i-15)**2 + (j-110)**2 < 25:
            draw(data, i, j, 150)
        elif (i-15)**2 + (j-110)**2 == 25 or (i-15)**2 + (j-110)**2 == 26:
            draw(data, i, j, 255)

# konwersja macierzy na obrazek i wyświetlenie
plt.imshow(data, interpolation='nearest')
plt.show()

# %% [markdown]
# b)

# %%
kernel = np.array([[1, 0, -1], [1, 0, -1], [1, 0, -1]])
kernel_size = 3
stride = 1

res = np.zeros((len(data[0]) - 2 * stride, len(data) - 2 * stride, 3))

for i in range(len(res)):
    for j in range(len(res[i])):
        for k in range(len(kernel)):
            for n in range(len(kernel[k])):
                res[i,j] += data[i+k, j+n] * kernel[k, n]


plt.imshow(res, interpolation='nearest')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# c)

# %%
kernel = np.array([[1, 0, -1], [1, 0, -1], [1, 0, -1]])
kernel_size = 3
stride = 2

res = np.zeros((int(len(data[0])/stride - 2), int(len(data)/stride - 2), 3))

for i in range(len(res)):
    for j in range(len(res[i])):
        for k in range(len(kernel)):
            for n in range(len(kernel[k])):
                res[i,j] += data[i*stride+k, j*stride+n] * kernel[k, n]


plt.imshow(res, interpolation='nearest')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# d)

# %%
kernel = np.array([[1, 1, 1], [0, 0, 0], [-1, -1, -1]])
kernel_size = 3
stride = 1

res = np.zeros((int(len(data[0])/stride - 2), int(len(data)/stride - 2), 3))

for i in range(len(res)):
    for j in range(len(res[i])):
        for k in range(len(kernel)):
            for n in range(len(kernel[k])):
                res[i,j] += data[i*stride+k, j*stride+n] * kernel[k, n]


plt.imshow(res, interpolation='nearest')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
kernel = np.array([[1, 1, 1], [0, 0, 0], [-1, -1, -1]])
kernel_size = 3
stride = 2

res = np.zeros((int(len(data[0])/stride - 2), int(len(data)/stride - 2), 3))

for i in range(len(res)):
    for j in range(len(res[i])):
        for k in range(len(kernel)):
            for n in range(len(kernel[k])):
                res[i,j] += data[i*stride+k, j*stride+n] * kernel[k, n]


plt.imshow(res, interpolation='nearest')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def convolve(kernel, stride):
    res = np.zeros((int(len(data[0])/stride - 2), int(len(data)/stride - 2), 3))

    for i in range(len(res)):
        for j in range(len(res[i])):
            for k in range(len(kernel)):
                for n in range(len(kernel[k])):
                    res[i,j] += data[i*stride+k, j*stride+n] * kernel[k, n]
    return res

fig, ax = plt.subplots(ncols=2, nrows=2)
ax[0,0].imshow(convolve(np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]]), 1), interpolation='nearest')
ax[0,1].imshow(convolve(np.array([[0, 1, 2], [-1, 0, 1], [-2, -1, 0]]), 1), interpolation='nearest')
ax[1,0].imshow(convolve(np.array([[1, 2, 1], [0, 0, 0], [-1, -2, -1]]), 1), interpolation='nearest')
ax[1,1].imshow(convolve(np.array([[1, 2, 0], [1, 0, -1], [0, -1, -2]]), 1), interpolation='nearest')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Zadanie 2.

# %%
from os import listdir
from keras.preprocessing.image import load_img


dataset_home = './dogs-cats-mini/'

for file in listdir(dataset_home):
    img = load_img(dataset_home + file)
    print(img)
    break
# Out:
# dog.11130.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=40x41 at 0x7FF20D0BA310>
